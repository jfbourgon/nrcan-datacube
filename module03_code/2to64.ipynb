# %%
import rasterio 
import matplotlib.pyplot as plt
from rasterio.plot import show_hist, show
from matplotlib import pyplot
import numpy
import os
import sys
import glob

# %%
def source_to_first (source_dem,resample,dec_factor):
    os.system("gdaladdo -r "+ resample +" -ro " + source_dem + " --config COMPRESS_OVERVIEW LZW " + dec_factor)
    ovr = '.ovr'
    ovr_path = r'{}{}'.format(source_dem,ovr) 
    new_path = r'C:/Users/Owner/COOP4/PortableGit/nrcan-datacube/module_03/M2/2_to_64/test/{}_{}.tif'.format(resample,dec_factor)
    os.rename(ovr_path,new_path)
source_dem = 'C:/Users/Owner/COOP4/PortableGit/nrcan-datacube/module_03\M2/2_to_64/test/dem-source22.tif'
resample = 'nearest'
dec_factor = '2'
source_to_first (source_dem,resample,dec_factor)

# %%
def overview (resample,dec_factor):
    factor_str = str(dec_factor)
    print(factor_str)
    cur = 'C:/Users/Owner/COOP4/PortableGit/nrcan-datacube/module_03/M2/2_to_64/test/{}_{}.tif'.format(resample,factor_str)
    print(cur)
    os.system("gdaladdo -r "+ resample +" -ro " + cur + " --config COMPRESS_OVERVIEW LZW " + factor_str)
    
    ovr = '.ovr'
    ovr_path = r'{}{}'.format(source_dem,ovr) 
    print(ovr_path)
    new_factor_str = str(dec_factor*2)
    new_path = r'C:/Users/Owner/COOP4/PortableGit/nrcan-datacube/module_03/M2/2_to_64/test/{}_{}.tif'.format(resample,new_factor_str)
    print(new_path)
    os.rename(ovr_path,new_path)
    
    cur = new_path
    print(cur)
    
    dec_factor = dec_factor * 2
    print(dec_factor)
    
    overview (resample,dec_factor)
overview('nearest',2)
# Out:
# 2
# C:/Users/Owner/COOP4/PortableGit/nrcan-datacube/module_03/M2/2_to_64/test/nearest_2.tif
# C:/Users/Owner/COOP4/PortableGit/nrcan-datacube/module_03\M2/2_to_64/test/dem-source22.tif.ovr
# C:/Users/Owner/COOP4/PortableGit/nrcan-datacube/module_03/M2/2_to_64/test/nearest_4.tif
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-26-95e3a89915f7> in <module>
#      21
#      22     overview (resample,dec_factor)
# ---> 23 overview('nearest',2)
#
# <ipython-input-26-95e3a89915f7> in overview(resample, dec_factor)
#      12     new_path = r'C:/Users/Owner/COOP4/PortableGit/nrcan-datacube/module_03/M2/2_to_64/test/{}_{}.tif'.format(resample,new_factor_str)
#      13     print(new_path)
# ---> 14     os.rename(ovr_path,new_path)
#      15
#      16     cur = new_path
#
# ...

# %%
def resample_img(resample, dec_factor):
    # create res-overview2
    print("gdaladdo -r "+ resample +" -ro " + source_dem + " --config COMPRESS_OVERVIEW LZW " + dec_factor)
    os.system("gdaladdo -r "+ resample +" -ro " + source_dem + " --config COMPRESS_OVERVIEW LZW " + dec_factor)
    cur_name = resample
    os.rename(filename,r'C:/Users/Owner/COOP4/PortableGit/nrcan-datacube/module_03/M2/2_to_64/{}_{}.tif'.format(cur_name,'2'))
    dec_factor = dec_factor * 2
    resample_img(dec_factor)

resample_list = ['nearest','average','bilinear','gauss','cubic','cubicspline','average_magphase','mode']
for i in resample_list:
    resample_img(i, dec_factor)
# Out:
# C://Users//Owner//COOP4//PortableGit//nrcan-datacube//module_03//M2//2_to_64\dem-source_22.tif.ovr
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-3-75bb5fe3ecec> in <module>
#       4             print(filename)
#       5             cur_name = 'nearest'
# ----> 6             os.rename(filename,r'C:/Users/Owner/COOP4/PortableGit/nrcan-datacube/module_03/M2/2_to_64/{}_{}.tif'.format(cur_name,'2'))
#
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'C://Users//Owner//COOP4//PortableGit//nrcan-datacube//module_03//M2//2_to_64\\dem-source_22.tif.ovr' -> 'C:/Users/Owner/COOP4/PortableGit/nrcan-datacube/module_03/M2/2_to_64/nearest_2.tif'

# %%
source_dem = "C:/Users/Owner/COOP4/PortableGit/nrcan-datacube/module_03/M2/2_to_64/dem-source_22.tif"
resample = 'nearest'
dec_factor = '2'
os.system("gdaladdo -r "+ resample +" -ro " + source_dem + " --config COMPRESS_OVERVIEW LZW " + dec_factor)
# Out:
# 0

# %%
# get data manually
resample_list = ['nearest','average','bilinear','gauss','cubic','cubicspline','average_magphase','mode']
source_dem = 'C:/Users/Owner/COOP4/PortableGit/nrcan-datacube/module_03/M2/2_to_64/dem-source_22.tif'
dec_factor = '2'
for cur in resample_list:
    print("gdaladdo -r "+ cur +" -ro " + source_dem + " --config COMPRESS_OVERVIEW LZW " + dec_factor)
    os.system("gdaladdo -r "+ cur +" -ro " + source_dem + " --config COMPRESS_OVERVIEW LZW " + dec_factor)
    os.rename(r'C:/Users/Owner/COOP4/PortableGit/nrcan-datacube/module_03/M2/2_to_64/dem-source_22.tif.ovr',r'C:/Users/Owner/COOP4/PortableGit/nrcan-datacube/module_03/M2/2_to_64/{}_{}.tif'.format(cur,dec_factor))
# Out:
# gdaladdo -r nearest -ro C:/Users/Owner/COOP4/PortableGit/nrcan-datacube/module_03/M2/2_to_64/dem-source_22.tif --config COMPRESS_OVERVIEW LZW 2
# gdaladdo -r average -ro C:/Users/Owner/COOP4/PortableGit/nrcan-datacube/module_03/M2/2_to_64/dem-source_22.tif --config COMPRESS_OVERVIEW LZW 2
# gdaladdo -r bilinear -ro C:/Users/Owner/COOP4/PortableGit/nrcan-datacube/module_03/M2/2_to_64/dem-source_22.tif --config COMPRESS_OVERVIEW LZW 2
# gdaladdo -r gauss -ro C:/Users/Owner/COOP4/PortableGit/nrcan-datacube/module_03/M2/2_to_64/dem-source_22.tif --config COMPRESS_OVERVIEW LZW 2
# gdaladdo -r cubic -ro C:/Users/Owner/COOP4/PortableGit/nrcan-datacube/module_03/M2/2_to_64/dem-source_22.tif --config COMPRESS_OVERVIEW LZW 2
# gdaladdo -r cubicspline -ro C:/Users/Owner/COOP4/PortableGit/nrcan-datacube/module_03/M2/2_to_64/dem-source_22.tif --config COMPRESS_OVERVIEW LZW 2
# ...

# %%
# Semi-Automation
cur_method = 'nearest'
########### modify name of current file ##########
cur_file = 'nearest_64.tif'


source_dem = 'C:/Users/Owner/COOP4/PortableGit/nrcan-datacube/module_03/M2/2_to_64/{}'.format(cur_file)
dec_factor = 2
########### modify dec_factor by multiplying 2 ##########
dec = str(dec_factor*64)
os.system("gdaladdo -r "+ cur_method +" -ro " + source_dem + " --config COMPRESS_OVERVIEW LZW " + str(dec_factor))
os.rename(r'C:/Users/Owner/COOP4/PortableGit/nrcan-datacube/module_03/M2/2_to_64/{}.ovr'.format(cur_file),
          r'C:/Users/Owner/COOP4/PortableGit/nrcan-datacube/module_03/M2/2_to_64/{}_{}.tif'.format(cur_method,dec))

# %%
import rasterio 
import matplotlib.pyplot as plt
from rasterio.plot import show_hist, show
from matplotlib import pyplot
import numpy
import os
import sys
import glob
import csv
import re
from pprint import pprint

# %%
path = 'C://Users//Owner//COOP4//PortableGit//nrcan-datacube//module_03//M2//2_to_64//64'
fields = ['Name', 'Resampling Method', 'Source','Overview', 'Driver', 'Data Type', 
          'crs', 'Width', 'Height', 'Nodata Pixels', 'Pixels with Values',
          'Pixel Size', 'Min', 'Max', 'Range', 'Mean', 'Median', 'Std', 'Var']
rows = [fields]

for filename in glob.glob(os.path.join(path, '*.tif')):
   with open(os.path.join(os.getcwd(), filename), 'r') as f: # open in readonly mode
    cog = rasterio.open(filename)
    cur_name = os.path.basename(filename).split('_')[0]
    resampling = os.path.basename(filename)[:-7]
    source = 'overview - 64'
    overview = 64
    
    # delete nodata value
    cog_ar = cog.read(1)
    cog_ar = numpy.where(cog_ar==cog.nodata,numpy.nan,cog_ar)
    
    # stats
    driver = str(cog.meta['driver'])
    dtype = str(cog.meta['dtype'])
    crs = str(cog.meta['crs'])
    width = cog.meta['width']
    height = cog.meta['height']
    nodata = len(cog_ar[numpy.isnan(cog_ar)])
    data_with_values = len(cog_ar[~numpy.isnan(cog_ar)])
    pixel_size = cog.transform[0]
    
    cog_min = numpy.nanmin(cog_ar)
    cog_max = numpy.nanmax(cog_ar)
    cog_range = cog_max-cog_min
    cog_mean = numpy.nanmean(cog_ar)
    cog_median = numpy.nanmedian(cog_ar)
    cog_std = numpy.nanstd(cog_ar)
    cog_var = numpy.nanvar(cog_ar)
    
    cur_row = [cur_name,
               resampling,
               overview,
               driver,
               dtype,
               crs,
               width,
               height,
               nodata,
               data_with_values,
               pixel_size,
               cog_min,
               cog_max,
               cog_range,
               cog_mean,
               cog_median,
               cog_std,
               cog_var]
    
    rows.append(cur_row)
    # name of csv file
    output = "C:/Users/Owner/COOP4/PortableGit/nrcan-datacube/module_03/M2/2_to_64/64/stats_{}.csv".format(cur_name)
    
    # writing to csv file 
    with open(output, 'w',newline='') as csvfile: 
        csvwriter = csv.writer(csvfile) 
        csvwriter.writerow(fields) 
        csvwriter.writerow(cur_row)

# %%
# name of csv file
output = "C:/Users/Owner/COOP4/PortableGit/nrcan-datacube/module_03/M2/2_to_64/64/stats_all.csv"

# writing to csv file 
with open(output, 'w',newline='') as csvfile: 
    csvwriter = csv.writer(csvfile) 
    csvwriter.writerows(rows)

# %%
source = "C:/Users/Owner/COOP4/PortableGit/nrcan-datacube/module_03/M2/2_to_64/64"
for filename in glob.glob(os.path.join(source, '*.tif')):
   with open(os.path.join(os.getcwd(), filename), 'r') as f: # open in readonly mode
    cog_sample = rasterio.open(filename)
    cur_name = os.path.basename(filename)[:-4]
    
    bound = str(cog_sample.bounds)
    crs = str(cog_sample.crs)
    dtype = str(cog_sample.dtypes[0])
    trans = str(cog_sample.transform)
    nodata = str(cog_sample.nodata)
    shape = str(cog_sample.shape)
    meta = str(cog_sample.meta)
    output = "{}_info".format(cur_name)
    f = open(output+'.txt',"w")
    f.write("stats: " + "\n" + 
            "bound: " + bound + "\n" + 
            "crs: " + crs + "\n" + 
            "dtype: " + dtype + 
            "transform: " + trans + 
            "nodata: " + nodata + 
            "shape: " + shape + 
            "metadata: " + meta)
    
    fig, (aximage, axhist) = pyplot.subplots(1, 2, figsize=(49,28))
    figtitle="{} sample cog and histogram".format(cur_name)
    fig.suptitle(figtitle,fontsize=30)
    #create histogram using rasterio show histogram, pass axes subplot handle to axhist
    bins=50
    show_hist(cog_sample, bins=bins, lw=0.0, 
              stacked=False, alpha=0.3,
              histtype='stepfilled',
              ax=axhist)
    axhist.set_title('')
    axhist.set_xlabel('elevation (m)')
    axhist.set_ylabel('')
    axhist.legend('')
    #create display image passing axes subplot handle to aximage
    show(cog_sample, cmap='gray',transform=cog_sample.transform, ax=aximage)
    #save the figure
    fname=source+cur_name+'.png'
    pyplot.savefig(fname,format='png')
# Out:
# C:\Users\Owner\miniconda3\envs\starrys597li\lib\site-packages\rasterio\__init__.py:207: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\Owner\miniconda3\envs\starrys597li\lib\site-packages\rasterio\__init__.py:207: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
